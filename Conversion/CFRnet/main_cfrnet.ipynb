# %% [markdown]
# Import libraries

# %%
#import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader
from cfrnet import CFRnet
import sys
from pathlib import Path
project_root = Path("/home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling")
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))
from utils import seed_everything
from metrics import auuc, auqc, lift, krcc

# %%
# %time train_df = pd.read_csv(r"/home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling/dataset/Hillstrom/Men/train_men.csv")
# %time test_df =  pd.read_csv(r"/home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling/dataset/Hillstrom/Men/test_men.csv")
# %time val_df = pd.read_csv(r"/home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling/dataset/Hillstrom/Men/val_men.csv")
# Out:
# CPU times: user 23.5 ms, sys: 6 ms, total: 29.5 ms
# Wall time: 29 ms
# CPU times: user 13.3 ms, sys: 2 ms, total: 15.3 ms
# Wall time: 15.2 ms
# CPU times: user 4.72 ms, sys: 1e+03 μs, total: 5.72 ms
# Wall time: 5.73 ms

# %%
in_features = ['recency', 'history_segment', 'history', 'mens', 'womens',
       'zip_code', 'newbie', 'channel_Multichannel', 'channel_Phone', 'channel_Web']
label_feature = ['spend']
treatment_feature = ['treatment']

# %%
X_train = train_df[in_features].values.astype(float) # type: ignore
y_train = train_df[label_feature].values.astype(float) # type: ignore
t_train = train_df[treatment_feature].values.astype(float) # type: ignore

X_test = test_df[in_features].values.astype(float) # type: ignore
y_test = test_df[label_feature].values.astype(float) # type: ignore
t_test = test_df[treatment_feature].values.astype(float) # type: ignore

X_val = val_df[in_features].values.astype(float) # type: ignore
y_val = val_df[label_feature].values.astype(float) # type: ignore
t_val = val_df[treatment_feature].values.astype(float) # type: ignore

# %%
print('X_train[:10]', X_train[:1].astype(float))
# Out:
# X_train[:10] [[-0.21435131  1.6331766   1.0667411   0.90252386 -1.1010233   1.07039981
#    1.00043033  2.70003843 -0.88552759 -0.88616046]]

# %%
print('y_train[:10]', y_train[:1].astype(float))
# Out:
# y_train[:10] [[0.]]

# %%
# Transform to tensor
def to_tensor(arr):
    return torch.tensor(arr, dtype=torch.float32)

x_men_train_t = to_tensor(X_train)
x_men_val_t = to_tensor(X_val)
x_men_test_t = to_tensor(X_test)

y_men_train_t = to_tensor(y_train).reshape(-1, 1)
y_men_val_t = to_tensor(y_val).reshape(-1, 1)
y_men_test_t = to_tensor(y_test).reshape(-1, 1)

# t_train/t_val/t_test cũng tương tự
t_men_train_t = to_tensor(t_train.astype(float)).reshape(-1, 1)
t_men_val_t = to_tensor(t_val.astype(float)).reshape(-1, 1)
t_men_test_t = to_tensor(t_test.astype(float)).reshape(-1, 1)

# Data loader
train_dataset = TensorDataset(x_men_train_t, t_men_train_t, y_men_train_t)
val_dataset = TensorDataset(x_men_val_t, t_men_val_t, y_men_val_t)
test_dataset = TensorDataset(x_men_test_t, t_men_test_t, y_men_test_t)

batch_size = 6400
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory = True)

print("-------------------------------------------------------------")
print("✅ Completed transform to tensor ✅")
print(f"Shape of train: x={x_men_train_t.shape}; y={y_men_train_t.shape}; t={t_men_train_t.shape}")
print(f"Shape of val: x={x_men_val_t.shape}; y={y_men_val_t.shape}; t={t_men_val_t.shape}")
print(f"Shape of test: x={x_men_test_t.shape}; y={y_men_test_t.shape}; t={t_men_test_t.shape}")
# Out:
# -------------------------------------------------------------
# ✅ Completed transform to tensor ✅
# Shape of train: x=torch.Size([25567, 10]); y=torch.Size([25567, 1]); t=torch.Size([25567, 1])
# Shape of val: x=torch.Size([4262, 10]); y=torch.Size([4262, 1]); t=torch.Size([4262, 1])
# Shape of test: x=torch.Size([12784, 10]); y=torch.Size([12784, 1]); t=torch.Size([12784, 1])

# %%
epochs = 150
alpha = 1
lr = 1e-4
wd = 1e-5
method = "mmd_rbf"
early_stop_metric = "qini"
ema = True
ema_alpha = 0.15
patience = 20
early_stop_start = 0
shared_hidden = 200
outcome_hidden = 100
activation = torch.nn.ReLU

print (f" epochs = {epochs}")
print (f" method = {method}")
print (f" alpha = {alpha}")
print (f" learning rate = {lr}")
print (f" weight decay = {wd}")
print (f" early stop = {early_stop_metric}")
print (f" use ema = {ema}")
print (f" ema alpha = {ema_alpha}")
print (f" patience = {patience}")
print (f" shared hidden = {shared_hidden}")
print (f" outcome hidden = {outcome_hidden}")
print (f"activation = {activation}")
# Out:
#  epochs = 150
#  method = mmd_rbf
#  alpha = 1
#  learning rate = 0.0001
#  weight decay = 1e-05
#  early stop = qini
#  use ema = True
#  ema alpha = 0.15
#  patience = 20
#  shared hidden = 200
#  outcome hidden = 100
# activation = <class 'torch.nn.modules.activation.ReLU'>

# %%
seed = 412312
seed_everything(seed)

cfr = CFRnet(input_dim=x_men_train_t.shape[1], epochs=epochs, 
                      alpha = alpha,
                      method=method,
                      learning_rate=lr, 
                      weight_decay=wd,
                      use_ema=ema,
                      ema_alpha=ema_alpha,
                      patience=patience,
                      shared_hidden=shared_hidden,
                      outcome_hidden=outcome_hidden,
                      early_stop_metric=early_stop_metric,
                      early_stop_start_epoch=early_stop_start,
                      activation=activation
)
cfr.fit(train_loader, val_loader)

print ("Complete training")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Evaluate on ORIGINAL test set ===
print("=" * 50)
print("Evaluating on ORIGINAL test set 🔃🔃🔃")
x_men_test_t_on_device = x_men_test_t.to(device)
y0_pred, y1_pred = cfr.predict(x_men_test_t_on_device)
uplift_pred = (y1_pred - y0_pred).cpu().numpy().flatten()
y_true = y_men_test_t.cpu().numpy().flatten()
t_true = t_men_test_t.cpu().numpy().flatten()

auuc_score = auuc(y_true, t_true, uplift_pred, bins=100, plot=True)
auqc_score = auqc(y_true, t_true, uplift_pred, bins=100, plot=True)
lift_score = lift(y_true, t_true, uplift_pred, h=0.3)
krcc_score = krcc(y_true, t_true, uplift_pred, bins=100)
ate_pred = uplift_pred.mean()
ate_true = y_true[t_true == 1].mean() - y_true[t_true == 0].mean()

print("-" * 40)
print("[ORIGINAL TEST SET]")
print(f"AUUC: {auuc_score:.3f}")
print(f"AUQC: {auqc_score:.3f}")
print(f"Lift: {lift_score:.3f}")
print(f"KRCC: {krcc_score:.3f}")
print(f"ATE (predicted): {ate_pred:.4f}")
print(f"ATE (true): {ate_true:.4f}")
print(f"ATE error: {abs(ate_pred - ate_true):.4f}")
# Out:
# Locked random seed: 412312
# 🔃🔃🔃Begin training Dragonnet🔃🔃🔃
# 📊 Early Stop Metric: QINI
# 📊 Early Stop Start Epoch: 1
# 📊 Strategy: Two-Stage EMA Filter (alpha=0.15)
#    EMA filters noise spikes, Raw Qini determines peak height
#    Select checkpoint: raw_qini is highest AND raw_qini >= ema_qini
# Epoch 1/150 | Loss: 437.0244 | Val Loss: 490.6410 | Val Qini: 0.3808 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.3808 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 2/150 | Loss: 638.7494 | Val Loss: 490.5783 | Val Qini: 0.3741 (patience: 1/20)EMA Trend: 0.3798 | (patience: 1/20)
# Epoch 3/150 | Loss: 294.7515 | Val Loss: 490.5114 | Val Qini: 0.3491 (patience: 2/20)EMA Trend: 0.3752 | (patience: 2/20)
# Epoch 4/150 | Loss: 424.6520 | Val Loss: 490.4352 | Val Qini: 0.3551 (patience: 3/20)EMA Trend: 0.3721 | (patience: 3/20)
# Epoch 5/150 | Loss: 356.9093 | Val Loss: 490.3489 | Val Qini: 0.3431 (patience: 4/20)EMA Trend: 0.3678 | (patience: 4/20)
# Epoch 6/150 | Loss: 328.5348 | Val Loss: 490.2509 | Val Qini: 0.3044 (patience: 5/20)EMA Trend: 0.3583 | (patience: 5/20)
# Epoch 7/150 | Loss: 503.2366 | Val Loss: 490.1383 | Val Qini: 0.2580 (patience: 6/20)EMA Trend: 0.3432 | (patience: 6/20)
# Epoch 8/150 | Loss: 320.2585 | Val Loss: 490.0087 | Val Qini: 0.2571 (patience: 7/20)EMA Trend: 0.3303 | (patience: 7/20)
# Epoch 9/150 | Loss: 416.2129 | Val Loss: 489.8587 | Val Qini: 0.2460 (patience: 8/20)EMA Trend: 0.3177 | (patience: 8/20)
# Epoch 10/150 | Loss: 251.3218 | Val Loss: 489.6865 | Val Qini: 0.2505 (patience: 9/20)EMA Trend: 0.3076 | (patience: 9/20)
# Epoch 11/150 | Loss: 457.7133 | Val Loss: 489.4924 | Val Qini: 0.2465 (patience: 10/20)EMA Trend: 0.2984 | (patience: 10/20)
# Epoch 12/150 | Loss: 540.8049 | Val Loss: 489.2809 | Val Qini: 0.2285 (patience: 11/20)EMA Trend: 0.2879 | (patience: 11/20)
# Epoch 13/150 | Loss: 251.9797 | Val Loss: 489.0561 | Val Qini: 0.2306 (patience: 12/20)EMA Trend: 0.2793 | (patience: 12/20)
# Epoch 14/150 | Loss: 289.3127 | Val Loss: 488.8265 | Val Qini: 0.2211 (patience: 13/20)EMA Trend: 0.2706 | (patience: 13/20)
# Epoch 15/150 | Loss: 474.2483 | Val Loss: 488.5985 | Val Qini: 0.2794 ✓ above trend but not peak (patience: 14/20)EMA Trend: 0.2719 | ✓ above trend but not peak (patience: 14/20)
# Epoch 16/150 | Loss: 460.9526 | Val Loss: 488.3819 | Val Qini: 0.5468 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.3132 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 17/150 | Loss: 439.4445 | Val Loss: 488.1763 | Val Qini: 0.6275 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0
# Epoch 40/150 | Loss: 657.6041 | Val Loss: 487.4109 | Val Qini: 0.7599 ✓ above trend but not peak (patience: 10/20)EMA Trend: 0.7477 | ✓ above trend but not peak (patience: 10/20)
# Epoch 41/150 | Loss: 518.7299 | Val Loss: 487.4008 | Val Qini: 0.7580 ✓ above trend but not peak (patience: 11/20)EMA Trend: 0.7493 | ✓ above trend but not peak (patience: 11/20)
# Epoch 42/150 | Loss: 652.2921 | Val Loss: 487.3845 | Val Qini: 0.7551 ✓ above trend but not peak (patience: 12/20)EMA Trend: 0.7501 | ✓ above trend but not peak (patience: 12/20)
# Epoch 43/150 | Loss: 369.6521 | Val Loss: 487.3549 | Val Qini: 0.7509 ✓ above trend but not peak (patience: 13/20)EMA Trend: 0.7502 | ✓ above trend but not peak (patience: 13/20)
# Epoch 44/150 | Loss: 488.7053 | Val Loss: 487.3400 | Val Qini: 0.7458 (patience: 14/20)EMA Trend: 0.7496 | (patience: 14/20)
# Epoch 45/150 | Loss: 649.0568 | Val Loss: 487.3159 | Val Qini: 0.7441 (patience: 15/20)EMA Trend: 0.7488 | (patience: 15/20)
# Epoch 46/150 | Loss: 462.4777 | Val Loss: 487.2852 | Val Qini: 0.7414 (patience: 16/20)EMA Trend: 0.7477 | (patience: 16/20)
# Epoch 47/150 | Loss: 398.8847 | Val Loss: 487.2636 | Val Qini: 0.7402 (patience: 17/20)EMA Trend: 0.7465 | (patience: 17/20)
# Epoch 48/150 | Loss: 794.3632 | Val Loss: 487.2552 | Val Qini: 0.7410 (patience: 18/20)EMA Trend: 0.7457 | (patience: 18/20)
# Epoch 49/150 | Loss: 502.8537 | Val Loss: 487.2511 | Val Qini: 0.7366 (patience: 19/20)EMA Trend: 0.7443 | (patience: 19/20)
# Epoch 50/150 | Loss: 459.1546 | Val Loss: 487.2352 | Val Qini: 0.7300 (patience: 20/20)EMA Trend: 0.7422 | (patience: 20/20)
#
# 🛑 Early stopping triggered at epoch 50!
#    No valid peak (raw ≥ trend) found in last 20 epochs
#
# ✅ Training completed! Restored model to epoch 30
#    Best Raw Qini: 0.7751
#    Final EMA Trend: 0.7422
#    Strategy: Selected highest peak that stayed above EMA trend
# Complete training
# ==================================================
# Evaluating on ORIGINAL test set 🔃🔃🔃
# /home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling/Revenue/CFRnet/cfrnet.py:270: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.float32, device=self.device)
# ----------------------------------------
# [ORIGINAL TEST SET]
# AUUC: 0.612
# AUQC: 0.610
# Lift: 1.058
# KRCC: 0.071
# ATE (predicted): 0.8512
# ATE (true): 0.5874
# ATE error: 0.2638

# %%
seed = 42
seed_everything(seed)

cfr = CFRnet(input_dim=x_men_train_t.shape[1], epochs=epochs, 
                      alpha = alpha,
                      method=method,
                      learning_rate=lr, 
                      weight_decay=wd,
                      use_ema=ema,
                      ema_alpha=ema_alpha,
                      patience=patience,
                      shared_hidden=shared_hidden,
                      outcome_hidden=outcome_hidden,
                      early_stop_metric=early_stop_metric,
                      early_stop_start_epoch=early_stop_start,
                      activation=activation
)
cfr.fit(train_loader, val_loader)

print ("Complete training")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Evaluate on ORIGINAL test set ===
print("=" * 50)
print("Evaluating on ORIGINAL test set 🔃🔃🔃")
x_men_test_t_on_device = x_men_test_t.to(device)
y0_pred, y1_pred = cfr.predict(x_men_test_t_on_device)
uplift_pred = (y1_pred - y0_pred).cpu().numpy().flatten()
y_true = y_men_test_t.cpu().numpy().flatten()
t_true = t_men_test_t.cpu().numpy().flatten()

auuc_score = auuc(y_true, t_true, uplift_pred, bins=100, plot=True)
auqc_score = auqc(y_true, t_true, uplift_pred, bins=100, plot=True)
lift_score = lift(y_true, t_true, uplift_pred, h=0.3)
krcc_score = krcc(y_true, t_true, uplift_pred, bins=100)
ate_pred = uplift_pred.mean()
ate_true = y_true[t_true == 1].mean() - y_true[t_true == 0].mean()

print("-" * 40)
print("[ORIGINAL TEST SET]")
print(f"AUUC: {auuc_score:.3f}")
print(f"AUQC: {auqc_score:.3f}")
print(f"Lift: {lift_score:.3f}")
print(f"KRCC: {krcc_score:.3f}")
print(f"ATE (predicted): {ate_pred:.4f}")
print(f"ATE (true): {ate_true:.4f}")
print(f"ATE error: {abs(ate_pred - ate_true):.4f}")
# Out:
# Locked random seed: 42
# 🔃🔃🔃Begin training Dragonnet🔃🔃🔃
# 📊 Early Stop Metric: QINI
# 📊 Early Stop Start Epoch: 1
# 📊 Strategy: Two-Stage EMA Filter (alpha=0.15)
#    EMA filters noise spikes, Raw Qini determines peak height
#    Select checkpoint: raw_qini is highest AND raw_qini >= ema_qini
# Epoch 1/150 | Loss: 332.0768 | Val Loss: 490.6268 | Val Qini: 0.1990 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.1990 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 2/150 | Loss: 598.3302 | Val Loss: 490.5742 | Val Qini: 0.1911 (patience: 1/20)EMA Trend: 0.1978 | (patience: 1/20)
# Epoch 3/150 | Loss: 412.7926 | Val Loss: 490.5181 | Val Qini: 0.2404 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.2042 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 4/150 | Loss: 470.3491 | Val Loss: 490.4562 | Val Qini: 0.3325 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.2234 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 5/150 | Loss: 470.6924 | Val Loss: 490.3878 | Val Qini: 0.3871 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.2480 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 6/150 | Loss: 166.3669 | Val Loss: 490.3112 | Val Qini: 0.4312 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.2755 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 7/150 | Loss: 436.1776 | Val Loss: 490.2242 | Val Qini: 0.4402 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.3002 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 8/150 | Loss: 336.4120 | Val Loss: 490.1247 | Val Qini: 0.4026 ✓ above trend but not peak (patience: 1/20)EMA Trend: 0.3155 | ✓ above trend but not peak (patience: 1/20)
# Epoch 9/150 | Loss: 316.5667 | Val Loss: 490.0050 | Val Qini: 0.3798 ✓ above trend but not peak (patience: 2/20)EMA Trend: 0.3252 | ✓ above trend but not peak (patience: 2/20)
# Epoch 10/150 | Loss: 483.9088 | Val Loss: 489.8642 | Val Qini: 0.3608 ✓ above trend but not peak (patience: 3/20)EMA Trend: 0.3305 | ✓ above trend but not peak (patience: 3/20)
# Epoch 11/150 | Loss: 400.5580 | Val Loss: 489.7025 | Val Qini: 0.3360 ✓ above trend but not peak (patience: 4/20)EMA Trend: 0.3313 | ✓ above trend but not peak (patience: 4/20)
# Epoch 34/150 | Loss: 554.3607 | Val Loss: 487.2935 | Val Qini: 0.7573 ✓ above trend but not peak (patience: 8/20)EMA Trend: 0.7223 | ✓ above trend but not peak (patience: 8/20)
# Epoch 35/150 | Loss: 552.4709 | Val Loss: 487.2683 | Val Qini: 0.7586 ✓ above trend but not peak (patience: 9/20)EMA Trend: 0.7277 | ✓ above trend but not peak (patience: 9/20)
# Epoch 36/150 | Loss: 276.1745 | Val Loss: 487.2223 | Val Qini: 0.7621 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.7329 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 37/150 | Loss: 397.2469 | Val Loss: 487.1972 | Val Qini: 0.7607 ✓ above trend but not peak (patience: 1/20)EMA Trend: 0.7371 | ✓ above trend but not peak (patience: 1/20)
# Epoch 38/150 | Loss: 246.8259 | Val Loss: 487.1712 | Val Qini: 0.7607 ✓ above trend but not peak (patience: 2/20)EMA Trend: 0.7406 | ✓ above trend but not peak (patience: 2/20)
# Epoch 39/150 | Loss: 335.8922 | Val Loss: 487.1674 | Val Qini: 0.7587 ✓ above trend but not peak (patience: 3/20)EMA Trend: 0.7433 | ✓ above trend but not peak (patience: 3/20)
# Epoch 40/150 | Loss: 363.8383 | Val Loss: 487.1560 | Val Qini: 0.7510 ✓ above trend but not peak (patience: 4/20)EMA Trend: 0.7445 | ✓ above trend but not peak (patience: 4/20)
# Epoch 41/150 | Loss: 365.9909 | Val Loss: 487.1453 | Val Qini: 0.7492 ✓ above trend but not peak (patience: 5/20)EMA Trend: 0.7452 | ✓ above trend but not peak (patience: 5/20)
# Epoch 42/150 | Loss: 515.1159 | Val Loss: 487.1574 | Val Qini: 0.7322 (patience: 6/20)EMA Trend: 0.7432 | (patience: 6/20)
# Epoch 43/150 | Loss: 229.4268 | Val Loss: 487.1326 | Val Qini: 0.7266 (patience: 7/20)EMA Trend: 0.7407 | (patience: 7/20)
# Epoch 44/150 | Loss: 515.4279 | Val Loss: 487.1394 | Val Qini: 0.7136 (patience: 8/20)EMA Trend: 0.7367 | (patience: 8/20)
# Epoch 45/150 | Loss: 581.9564 | Val Loss: 487.1568 | Val Qini: 0.6914 (patience: 9/20)EMA Trend: 0.7299 | (patience: 9/20)
# Epoch 46/150 | Loss: 254.4702 | Val Loss: 487.1344 | Val Qini: 0.6908 (patience: 10/20)EMA Trend: 0.7240 | (patience: 10/20)
# Epoch 47/150 | Loss: 245.6422 | Val Loss: 487.1216 | Val Qini: 0.6831 (patience: 11/20)EMA Trend: 0.7179 | (patience: 11/20)
# Epoch 48/150 | Loss: 593.4404 | Val Loss: 487.1253 | Val Qini: 0.6799 (patience: 12/20)EMA Trend: 0.7122 | (patience: 12/20)
# Epoch 49/150 | Loss: 395.2460 | Val Loss: 487.1136 | Val Qini: 0.6736 (patience: 13/20)EMA Trend: 0.7064 | (patience: 13/20)
# Epoch 50/150 | Loss: 530.3347 | Val Loss: 487.1203 | Val Qini: 0.6710 (patience: 14/20)EMA Trend: 0.7011 | (patience: 14/20)
# Epoch 51/150 | Loss: 477.3965 | Val Loss: 487.1004 | Val Qini: 0.6682 (patience: 15/20)EMA Trend: 0.6962 | (patience: 15/20)
# Epoch 52/150 | Loss: 524.7182 | Val Loss: 487.1151 | Val Qini: 0.6607 (patience: 16/20)EMA Trend: 0.6908 | (patience: 16/20)
# Epoch 53/150 | Loss: 526.3051 | Val Loss: 487.1282 | Val Qini: 0.6469 (patience: 17/20)EMA Trend: 0.6842 | (patience: 17/20)
# Epoch 54/150 | Loss: 528.9200 | Val Loss: 487.1483 | Val Qini: 0.6275 (patience: 18/20)EMA Trend: 0.6757 | (patience: 18/20)
# Epoch 55/150 | Loss: 318.8321 | Val Loss: 487.1537 | Val Qini: 0.6145 (patience: 19/20)EMA Trend: 0.6665 | (patience: 19/20)
# Epoch 56/150 | Loss: 351.4442 | Val Loss: 487.1577 | Val Qini: 0.6047 (patience: 20/20)EMA Trend: 0.6573 | (patience: 20/20)
#
# 🛑 Early stopping triggered at epoch 56!
#    No valid peak (raw ≥ trend) found in last 20 epochs
#
# ✅ Training completed! Restored model to epoch 36
#    Best Raw Qini: 0.7621
#    Final EMA Trend: 0.6573
#    Strategy: Selected highest peak that stayed above EMA trend
# Complete training
# ==================================================
# Evaluating on ORIGINAL test set 🔃🔃🔃
# /home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling/Revenue/CFRnet/cfrnet.py:270: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.float32, device=self.device)
# ----------------------------------------
# [ORIGINAL TEST SET]
# AUUC: 0.531
# AUQC: 0.528
# Lift: 0.451
# KRCC: 0.042
# ATE (predicted): 0.7948
# ATE (true): 0.5874
# ATE error: 0.2073

# %%
seed =1874
seed_everything(seed)

cfr = CFRnet(input_dim=x_men_train_t.shape[1], epochs=epochs, 
                      alpha = alpha,
                      method=method,
                      learning_rate=lr, 
                      weight_decay=wd,
                      use_ema=ema,
                      ema_alpha=ema_alpha,
                      patience=patience,
                      shared_hidden=shared_hidden,
                      outcome_hidden=outcome_hidden,
                      early_stop_metric=early_stop_metric,
                      early_stop_start_epoch=early_stop_start,
                      activation=activation
)
cfr.fit(train_loader, val_loader)

print ("Complete training")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Evaluate on ORIGINAL test set ===
print("=" * 50)
print("Evaluating on ORIGINAL test set 🔃🔃🔃")
x_men_test_t_on_device = x_men_test_t.to(device)
y0_pred, y1_pred = cfr.predict(x_men_test_t_on_device)
uplift_pred = (y1_pred - y0_pred).cpu().numpy().flatten()
y_true = y_men_test_t.cpu().numpy().flatten()
t_true = t_men_test_t.cpu().numpy().flatten()

auuc_score = auuc(y_true, t_true, uplift_pred, bins=100, plot=True)
auqc_score = auqc(y_true, t_true, uplift_pred, bins=100, plot=True)
lift_score = lift(y_true, t_true, uplift_pred, h=0.3)
krcc_score = krcc(y_true, t_true, uplift_pred, bins=100)
ate_pred = uplift_pred.mean()
ate_true = y_true[t_true == 1].mean() - y_true[t_true == 0].mean()

print("-" * 40)
print("[ORIGINAL TEST SET]")
print(f"AUUC: {auuc_score:.3f}")
print(f"AUQC: {auqc_score:.3f}")
print(f"Lift: {lift_score:.3f}")
print(f"KRCC: {krcc_score:.3f}")
print(f"ATE (predicted): {ate_pred:.4f}")
print(f"ATE (true): {ate_true:.4f}")
print(f"ATE error: {abs(ate_pred - ate_true):.4f}")
# Epoch 50/150 | Loss: 500.2111 | Val Loss: 487.1906 | Val Qini: 0.7642 (patience: 8/20)EMA Trend: 0.7653 | (patience: 8/20)
# Epoch 51/150 | Loss: 308.4171 | Val Loss: 487.1837 | Val Qini: 0.7573 (patience: 9/20)EMA Trend: 0.7641 | (patience: 9/20)
# Epoch 52/150 | Loss: 340.7645 | Val Loss: 487.1865 | Val Qini: 0.7516 (patience: 10/20)EMA Trend: 0.7622 | (patience: 10/20)
# Epoch 53/150 | Loss: 557.8333 | Val Loss: 487.2061 | Val Qini: 0.7440 (patience: 11/20)EMA Trend: 0.7595 | (patience: 11/20)
# Epoch 54/150 | Loss: 597.9968 | Val Loss: 487.2272 | Val Qini: 0.7359 (patience: 12/20)EMA Trend: 0.7559 | (patience: 12/20)
# Epoch 55/150 | Loss: 503.2654 | Val Loss: 487.2154 | Val Qini: 0.7294 (patience: 13/20)EMA Trend: 0.7520 | (patience: 13/20)
# Epoch 56/150 | Loss: 345.5050 | Val Loss: 487.1870 | Val Qini: 0.7267 (patience: 14/20)EMA Trend: 0.7482 | (patience: 14/20)
# Epoch 57/150 | Loss: 330.9762 | Val Loss: 487.1697 | Val Qini: 0.7231 (patience: 15/20)EMA Trend: 0.7444 | (patience: 15/20)
# Epoch 58/150 | Loss: 240.1076 | Val Loss: 487.1464 | Val Qini: 0.7165 (patience: 16/20)EMA Trend: 0.7402 | (patience: 16/20)
# Epoch 59/150 | Loss: 422.3335 | Val Loss: 487.1130 | Val Qini: 0.7136 (patience: 17/20)EMA Trend: 0.7362 | (patience: 17/20)
# Epoch 60/150 | Loss: 483.7476 | Val Loss: 487.0983 | Val Qini: 0.7051 (patience: 18/20)EMA Trend: 0.7316 | (patience: 18/20)
# Epoch 61/150 | Loss: 413.7491 | Val Loss: 487.0769 | Val Qini: 0.6977 (patience: 19/20)EMA Trend: 0.7265 | (patience: 19/20)
# Epoch 62/150 | Loss: 686.4332 | Val Loss: 487.0620 | Val Qini: 0.6924 (patience: 20/20)EMA Trend: 0.7214 | (patience: 20/20)
#
# 🛑 Early stopping triggered at epoch 62!
#    No valid peak (raw ≥ trend) found in last 20 epochs
#
# ✅ Training completed! Restored model to epoch 42
#    Best Raw Qini: 0.7779
#    Final EMA Trend: 0.7214
#    Strategy: Selected highest peak that stayed above EMA trend
# Complete training
# ==================================================
# Evaluating on ORIGINAL test set 🔃🔃🔃
# /home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling/Revenue/CFRnet/cfrnet.py:270: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.float32, device=self.device)
# ----------------------------------------
# [ORIGINAL TEST SET]
# AUUC: 0.528
# AUQC: 0.525
# Lift: 0.626
# KRCC: 0.033
# ATE (predicted): 0.7902
# ATE (true): 0.5874
# ATE error: 0.2027

# %%
seed = 902745
seed_everything(seed)

cfr = CFRnet(input_dim=x_men_train_t.shape[1], epochs=epochs, 
                      alpha = alpha,
                      method=method,
                      learning_rate=lr, 
                      weight_decay=wd,
                      use_ema=ema,
                      ema_alpha=ema_alpha,
                      patience=patience,
                      shared_hidden=shared_hidden,
                      outcome_hidden=outcome_hidden,
                      early_stop_metric=early_stop_metric,
                      early_stop_start_epoch=early_stop_start,
                      activation=activation
)
cfr.fit(train_loader, val_loader)

print ("Complete training")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Evaluate on ORIGINAL test set ===
print("=" * 50)
print("Evaluating on ORIGINAL test set 🔃🔃🔃")
x_men_test_t_on_device = x_men_test_t.to(device)
y0_pred, y1_pred = cfr.predict(x_men_test_t_on_device)
uplift_pred = (y1_pred - y0_pred).cpu().numpy().flatten()
y_true = y_men_test_t.cpu().numpy().flatten()
t_true = t_men_test_t.cpu().numpy().flatten()

auuc_score = auuc(y_true, t_true, uplift_pred, bins=100, plot=True)
auqc_score = auqc(y_true, t_true, uplift_pred, bins=100, plot=True)
lift_score = lift(y_true, t_true, uplift_pred, h=0.3)
krcc_score = krcc(y_true, t_true, uplift_pred, bins=100)
ate_pred = uplift_pred.mean()
ate_true = y_true[t_true == 1].mean() - y_true[t_true == 0].mean()

print("-" * 40)
print("[ORIGINAL TEST SET]")
print(f"AUUC: {auuc_score:.3f}")
print(f"AUQC: {auqc_score:.3f}")
print(f"Lift: {lift_score:.3f}")
print(f"KRCC: {krcc_score:.3f}")
print(f"ATE (predicted): {ate_pred:.4f}")
print(f"ATE (true): {ate_true:.4f}")
print(f"ATE error: {abs(ate_pred - ate_true):.4f}")
# Out:
# Locked random seed: 902745
# 🔃🔃🔃Begin training Dragonnet🔃🔃🔃
# 📊 Early Stop Metric: QINI
# 📊 Early Stop Start Epoch: 1
# 📊 Strategy: Two-Stage EMA Filter (alpha=0.15)
#    EMA filters noise spikes, Raw Qini determines peak height
#    Select checkpoint: raw_qini is highest AND raw_qini >= ema_qini
# Epoch 1/150 | Loss: 524.7335 | Val Loss: 490.6086 | Val Qini: 0.6930 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.6930 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 2/150 | Loss: 231.2861 | Val Loss: 490.5493 | Val Qini: 0.6096 (patience: 1/20)EMA Trend: 0.6805 | (patience: 1/20)
# Epoch 3/150 | Loss: 546.6509 | Val Loss: 490.4916 | Val Qini: 0.4455 (patience: 2/20)EMA Trend: 0.6452 | (patience: 2/20)
# Epoch 4/150 | Loss: 527.4208 | Val Loss: 490.4306 | Val Qini: 0.3925 (patience: 3/20)EMA Trend: 0.6073 | (patience: 3/20)
# Epoch 5/150 | Loss: 344.4892 | Val Loss: 490.3643 | Val Qini: 0.4457 (patience: 4/20)EMA Trend: 0.5831 | (patience: 4/20)
# Epoch 6/150 | Loss: 289.6888 | Val Loss: 490.2887 | Val Qini: 0.4981 (patience: 5/20)EMA Trend: 0.5703 | (patience: 5/20)
# Epoch 7/150 | Loss: 374.2393 | Val Loss: 490.2026 | Val Qini: 0.5869 ✓ above trend but not peak (patience: 6/20)EMA Trend: 0.5728 | ✓ above trend but not peak (patience: 6/20)
# Epoch 8/150 | Loss: 597.4529 | Val Loss: 490.1060 | Val Qini: 0.6666 ✓ above trend but not peak (patience: 7/20)EMA Trend: 0.5869 | ✓ above trend but not peak (patience: 7/20)
# Epoch 9/150 | Loss: 464.0096 | Val Loss: 489.9957 | Val Qini: 0.7049 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.
# Epoch 35/150 | Loss: 456.7865 | Val Loss: 487.2267 | Val Qini: 0.8303 ✓ above trend but not peak (patience: 6/20)EMA Trend: 0.8249 | ✓ above trend but not peak (patience: 6/20)
# Epoch 36/150 | Loss: 397.6885 | Val Loss: 487.2315 | Val Qini: 0.8275 ✓ above trend but not peak (patience: 7/20)EMA Trend: 0.8253 | ✓ above trend but not peak (patience: 7/20)
# Epoch 37/150 | Loss: 334.2083 | Val Loss: 487.2261 | Val Qini: 0.8203 (patience: 8/20)EMA Trend: 0.8246 | (patience: 8/20)
# Epoch 38/150 | Loss: 422.8976 | Val Loss: 487.2231 | Val Qini: 0.8141 (patience: 9/20)EMA Trend: 0.8230 | (patience: 9/20)
# Epoch 39/150 | Loss: 325.8083 | Val Loss: 487.2019 | Val Qini: 0.8152 (patience: 10/20)EMA Trend: 0.8218 | (patience: 10/20)
# Epoch 40/150 | Loss: 502.5957 | Val Loss: 487.2051 | Val Qini: 0.8119 (patience: 11/20)EMA Trend: 0.8203 | (patience: 11/20)
# Epoch 41/150 | Loss: 372.1299 | Val Loss: 487.1780 | Val Qini: 0.8124 (patience: 12/20)EMA Trend: 0.8192 | (patience: 12/20)
# Epoch 42/150 | Loss: 603.1076 | Val Loss: 487.1611 | Val Qini: 0.8077 (patience: 13/20)EMA Trend: 0.8174 | (patience: 13/20)
# Epoch 43/150 | Loss: 518.8492 | Val Loss: 487.1219 | Val Qini: 0.8122 (patience: 14/20)EMA Trend: 0.8166 | (patience: 14/20)
# Epoch 44/150 | Loss: 361.8457 | Val Loss: 487.1140 | Val Qini: 0.8068 (patience: 15/20)EMA Trend: 0.8152 | (patience: 15/20)
# Epoch 45/150 | Loss: 540.3850 | Val Loss: 487.0871 | Val Qini: 0.8096 (patience: 16/20)EMA Trend: 0.8143 | (patience: 16/20)
# Epoch 46/150 | Loss: 541.4460 | Val Loss: 487.0698 | Val Qini: 0.8043 (patience: 17/20)EMA Trend: 0.8128 | (patience: 17/20)
# Epoch 47/150 | Loss: 334.6052 | Val Loss: 487.0599 | Val Qini: 0.7994 (patience: 18/20)EMA Trend: 0.8108 | (patience: 18/20)
# Epoch 48/150 | Loss: 396.8665 | Val Loss: 487.0578 | Val Qini: 0.7935 (patience: 19/20)EMA Trend: 0.8082 | (patience: 19/20)
# Epoch 49/150 | Loss: 376.3518 | Val Loss: 487.0414 | Val Qini: 0.7910 (patience: 20/20)EMA Trend: 0.8056 | (patience: 20/20)
#
# 🛑 Early stopping triggered at epoch 49!
#    No valid peak (raw ≥ trend) found in last 20 epochs
#
# ✅ Training completed! Restored model to epoch 29
#    Best Raw Qini: 0.8410
#    Final EMA Trend: 0.8056
#    Strategy: Selected highest peak that stayed above EMA trend
# Complete training
# ==================================================
# Evaluating on ORIGINAL test set 🔃🔃🔃
# /home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling/Revenue/CFRnet/cfrnet.py:270: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.float32, device=self.device)
# ----------------------------------------
# [ORIGINAL TEST SET]
# AUUC: 0.633
# AUQC: 0.630
# Lift: 1.595
# KRCC: 0.081
# ATE (predicted): 0.8558
# ATE (true): 0.5874
# ATE error: 0.2684

# %%
seed = 1
seed_everything(seed)

cfr = CFRnet(input_dim=x_men_train_t.shape[1], epochs=epochs, 
                      alpha = alpha,
                      method=method,
                      learning_rate=lr, 
                      weight_decay=wd,
                      use_ema=ema,
                      ema_alpha=ema_alpha,
                      patience=patience,
                      shared_hidden=shared_hidden,
                      outcome_hidden=outcome_hidden,
                      early_stop_metric=early_stop_metric,
                      early_stop_start_epoch=early_stop_start,
                      activation=activation
)
cfr.fit(train_loader, val_loader)

print ("Complete training")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Evaluate on ORIGINAL test set ===
print("=" * 50)
print("Evaluating on ORIGINAL test set 🔃🔃🔃")
x_men_test_t_on_device = x_men_test_t.to(device)
y0_pred, y1_pred = cfr.predict(x_men_test_t_on_device)
uplift_pred = (y1_pred - y0_pred).cpu().numpy().flatten()
y_true = y_men_test_t.cpu().numpy().flatten()
t_true = t_men_test_t.cpu().numpy().flatten()

auuc_score = auuc(y_true, t_true, uplift_pred, bins=100, plot=True)
auqc_score = auqc(y_true, t_true, uplift_pred, bins=100, plot=True)
lift_score = lift(y_true, t_true, uplift_pred, h=0.3)
krcc_score = krcc(y_true, t_true, uplift_pred, bins=100)
ate_pred = uplift_pred.mean()
ate_true = y_true[t_true == 1].mean() - y_true[t_true == 0].mean()

print("-" * 40)
print("[ORIGINAL TEST SET]")
print(f"AUUC: {auuc_score:.3f}")
print(f"AUQC: {auqc_score:.3f}")
print(f"Lift: {lift_score:.3f}")
print(f"KRCC: {krcc_score:.3f}")
print(f"ATE (predicted): {ate_pred:.4f}")
print(f"ATE (true): {ate_true:.4f}")
print(f"ATE error: {abs(ate_pred - ate_true):.4f}")
# Out:
# Locked random seed: 1
# 🔃🔃🔃Begin training Dragonnet🔃🔃🔃
# 📊 Early Stop Metric: QINI
# 📊 Early Stop Start Epoch: 1
# 📊 Strategy: Two-Stage EMA Filter (alpha=0.15)
#    EMA filters noise spikes, Raw Qini determines peak height
#    Select checkpoint: raw_qini is highest AND raw_qini >= ema_qini
# Epoch 1/150 | Loss: 293.1359 | Val Loss: 490.7155 | Val Qini: 0.5421 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.5421 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 2/150 | Loss: 397.2821 | Val Loss: 490.6641 | Val Qini: 0.5715 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.5465 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 3/150 | Loss: 411.0444 | Val Loss: 490.6092 | Val Qini: 0.6013 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.5547 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 4/150 | Loss: 544.9208 | Val Loss: 490.5471 | Val Qini: 0.6849 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.5742 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 5/150 | Loss: 461.2090 | Val Loss: 490.4780 | Val Qini: 0.7437 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.5996 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 6/150 | Loss: 497.5440 | Val Loss: 490.3952 | Val Qini: 0.7463 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.6216 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 7/150 | Loss: 464.1660 | Val Loss: 490.2956 | Val Qini: 0.7535 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.6414 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 8/150 | Loss: 317.4966 | Val Loss: 490.1750 | Val Qini: 0.7750 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.6615 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 9/150 | Loss: 278.8558 | Val Loss: 490.0278 | Val Qini: 0.8016 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.6825 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 10/150 | Loss: 374.7906 | Val Loss: 489.8502 | Val Qini: 0.8168 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.7026 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 11/150 | Loss: 280.1050 | Val Loss: 489.6414 | Val Qini: 0.8248 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.7210 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 12/150 | Loss: 335.7448 | Val Loss: 489.3982 | Val Qini: 0.8183 ✓ above trend but not peak (patience: 1/20)EMA Trend: 0.7356 | ✓ above trend but not peak (patience: 1/20)
# Epoch 13/150 | Loss: 489.9434 | Val Loss: 489.1230 | Val Qini: 0.8240 ✓ above trend but not peak (patience: 2/20)EMA Trend: 0.7488 | ✓ above trend but not peak (patience: 2/20)
# Epoch 14/150 | Loss: 334.1655 | Val Loss: 488.8151 | Val Qini: 0.8283 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.7607 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 15/150 | Loss: 459.2171 | Val Loss: 488.4844 | Val Qini: 0.8247 ✓ above trend but not peak (patience: 1/20)EMA Trend: 0.7703 | ✓ above trend but not peak (patience: 1/20)
# Epoch 16/150 | Loss: 360.4073 | Val Loss: 488.1513 | Val Qini: 0.8233 ✓ above trend but not peak (patience: 2/20)EMA Trend: 0.7783 | ✓ above trend but not peak (patience: 2/20)
# Epoch 17/150 | Loss: 565.8173 | Val Loss: 487.8402 | Val Qini: 0.8258 ✓ above trend but not peak (patience: 3/20)EMA Trend: 0.7854 | ✓ above trend but not peak (patience: 3/20)
# Epoch 18/150 | Loss: 621.7258 | Val Loss: 487.6046 | Val Qini: 0.8300 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.7921 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 19/150 | Loss: 352.9659 | Val Loss: 487.4506 | Val Qini: 0.8316 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.7980 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 20/150 | Loss: 525.6453 | Val Loss: 487.3595 | Val Qini: 0.8378 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.8040 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 21/150 | Loss: 531.7938 | Val Loss: 487.3101 | Val Qini: 0.8373 ✓ above trend but not peak (patience: 1/20)EMA Trend: 0.8090 | ✓ above trend but not peak (patience: 1/20)
# Epoch 22/150 | Loss: 379.6801 | Val Loss: 487.2707 | Val Qini: 0.8389 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.8135 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 23/150 | Loss: 458.8899 | Val Loss: 487.2445 | Val Qini: 0.8416 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.8177 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 24/150 | Loss: 584.3176 | Val Loss: 487.2278 | Val Qini: 0.8378 ✓ above trend but not peak (patience: 1/20)EMA Trend: 0.8207 | ✓ above trend but not peak (patience: 1/20)
# Epoch 25/150 | Loss: 637.8085 | Val Loss: 487.2249 | Val Qini: 0.8375 ✓ above trend but not peak (patience: 2/20)EMA Trend: 0.8232 | ✓ above trend but not peak (patience: 2/20)
# Epoch 26/150 | Loss: 378.0917 | Val Loss: 487.2241 | Val Qini: 0.8387 ✓ above trend but not peak (patience: 3/20)EMA Trend: 0.8256 | ✓ above trend but not peak (patience: 3/20)
# Epoch 27/150 | Loss: 411.9786 | Val Loss: 487.2444 | Val Qini: 0.8338 ✓ above trend but not peak (patience: 4/20)EMA Trend: 0.8268 | ✓ above trend but not peak (patience: 4/20)
# Epoch 28/150 | Loss: 408.9686 | Val Loss: 487.2414 | Val Qini: 0.8324 ✓ above trend but not peak (patience: 5/20)EMA Trend: 0.8276 | ✓ above trend but not peak (patience: 5/20)
# Epoch 29/150 | Loss: 198.9214 | Val Loss: 487.2488 | Val Qini: 0.8305 ✓ above trend but not peak (patience: 6/20)EMA Trend: 0.8281 | ✓ above trend but not peak (patience: 6/20)
# Epoch 30/150 | Loss: 364.2373 | Val Loss: 487.2430 | Val Qini: 0.8303 ✓ above trend but not peak (patience: 7/20)EMA Trend: 0.8284 | ✓ above trend but not peak (patience: 7/20)
# Epoch 31/150 | Loss: 321.3638 | Val Loss: 487.2320 | Val Qini: 0.8323 ✓ above trend but not peak (patience: 8/20)EMA Trend: 0.8290 | ✓ above trend but not peak (patience: 8/20)
# Epoch 32/150 | Loss: 379.0133 | Val Loss: 487.2101 | Val Qini: 0.8304 ✓ above trend but not peak (patience: 9/20)EMA Trend: 0.8292 | ✓ above trend but not peak (patience: 9/20)
# Epoch 33/150 | Loss: 275.9052 | Val Loss: 487.1908 | Val Qini: 0.8288 (patience: 10/20)EMA Trend: 0.8291 | (patience: 10/20)
# Epoch 34/150 | Loss: 400.0403 | Val Loss: 487.1756 | Val Qini: 0.8305 ✓ above trend but not peak (patience: 11/20)EMA Trend: 0.8293 | ✓ above trend but not peak (patience: 11/20)
# Epoch 35/150 | Loss: 465.6863 | Val Loss: 487.1518 | Val Qini: 0.8295 ✓ above trend but not peak (patience: 12/20)EMA Trend: 0.8294 | ✓ above trend but not peak (patience: 12/20)
# Epoch 36/150 | Loss: 241.1576 | Val Loss: 487.1100 | Val Qini: 0.8333 ✓ above trend but not peak (patience: 13/20)EMA Trend: 0.8300 | ✓ above trend but not peak (patience: 13/20)
# Epoch 37/150 | Loss: 535.9068 | Val Loss: 487.0876 | Val Qini: 0.8323 ✓ above trend but not peak (patience: 14/20)EMA Trend: 0.8303 | ✓ above trend but not peak (patience: 14/20)
# Epoch 38/150 | Loss: 350.7990 | Val Loss: 487.0683 | Val Qini: 0.8332 ✓ above trend but not peak (patience: 15/20)EMA Trend: 0.8308 | ✓ above trend but not peak (patience: 15/20)
# Epoch 39/150 | Loss: 284.4116 | Val Loss: 487.0680 | Val Qini: 0.8305 (patience: 16/20)EMA Trend: 0.8307 | (patience: 16/20)
# Epoch 40/150 | Loss: 637.7793 | Val Loss: 487.0677 | Val Qini: 0.8321 ✓ above trend but not peak (patience: 17/20)EMA Trend: 0.8309 | ✓ above trend but not peak (patience: 17/20)
# Epoch 41/150 | Loss: 680.5482 | Val Loss: 487.0668 | Val Qini: 0.8301 (patience: 18/20)EMA Trend: 0.8308 | (patience: 18/20)
# Epoch 42/150 | Loss: 561.3364 | Val Loss: 487.0540 | Val Qini: 0.8300 (patience: 19/20)EMA Trend: 0.8307 | (patience: 19/20)
# Epoch 43/150 | Loss: 371.4826 | Val Loss: 487.0362 | Val Qini: 0.8303 (patience: 20/20)EMA Trend: 0.8306 | (patience: 20/20)
#
# 🛑 Early stopping triggered at epoch 43!
#    No valid peak (raw ≥ trend) found in last 20 epochs
#
# ✅ Training completed! Restored model to epoch 23
#    Best Raw Qini: 0.8416
#    Final EMA Trend: 0.8306
#    Strategy: Selected highest peak that stayed above EMA trend
# Complete training
# ==================================================
# Evaluating on ORIGINAL test set 🔃🔃🔃
# /home/ducm/Benchmark-conversion-vs-revenue-uplift-modeling/Revenue/CFRnet/cfrnet.py:270: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.float32, device=self.device)
# ----------------------------------------
# [ORIGINAL TEST SET]
# AUUC: 0.595
# AUQC: 0.591
# Lift: 0.818
# KRCC: 0.037
# ATE (predicted): 0.9044
# ATE (true): 0.5874
# ATE error: 0.3169
