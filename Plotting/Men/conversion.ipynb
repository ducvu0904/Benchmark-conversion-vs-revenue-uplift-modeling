# %%
from pathlib import Path
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader

# Ensure project root is importable regardless of current working directory.
repo_root = Path.cwd().resolve()
while repo_root != repo_root.parent and not (repo_root / "Conversion").exists():
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from Conversion.Tarnet.tarnet import Tarnet
from Conversion.CFRnet.cfrnet import CFRnet as Cfrnet
from Conversion.Dragonnet.dragonnet import Dragonnet
from xgboost import XGBClassifier # SỬ DỤNG XGBClassifier CHO CONVERSION
from lightgbm import LGBMClassifier # SỬ DỤNG LGBMClassifier CHO CONVERSION
from sklift.models import SoloModel, TwoModels
from metrics import auqc, auuc
from utils import seed_everything
# Example usage
# tarnet_model = Tarnet(input_dim=..., hidden_dim=...)
# cfrnet_model = Cfrnet(input_dim=..., hidden_dim=...)
# dragonnet_model = Dragonnet(input_dim=..., hidden_dim=...)

# %%
# %time train_df = pd.read_csv(r"/home/ducvu0904/Documents/Lab/Conversion vs revenue benchmarking/dataset/Hillstrom/Men/train_men.csv")
# %time test_df =  pd.read_csv(r"/home/ducvu0904/Documents/Lab/Conversion vs revenue benchmarking/dataset/Hillstrom/Men/test_men.csv")
# %time val_df = pd.read_csv(r"/home/ducvu0904/Documents/Lab/Conversion vs revenue benchmarking/dataset/Hillstrom/Men/val_men.csv")
# Out:
# CPU times: user 24 ms, sys: 8.15 ms, total: 32.2 ms
# Wall time: 31.5 ms
# CPU times: user 13.9 ms, sys: 1.01 ms, total: 14.9 ms
# Wall time: 14.6 ms
# CPU times: user 4.54 ms, sys: 9 μs, total: 4.54 ms
# Wall time: 4.52 ms

# %%
in_features = ['recency', 'history_segment', 'history', 'mens', 'womens',
       'zip_code', 'newbie', 'channel_Multichannel', 'channel_Phone', 'channel_Web']
label_feature = ['conversion']
treatment_feature = ['treatment']

# %%
X_train = train_df[in_features].values.astype(float) # type: ignore
y_train = train_df[label_feature].values.astype(float) # type: ignore
t_train = train_df[treatment_feature].values.astype(float) # type: ignore

X_test = test_df[in_features].values.astype(float) # type: ignore
y_test = test_df[label_feature].values.astype(float) # type: ignore
t_test = test_df[treatment_feature].values.astype(float) # type: ignore

X_val = val_df[in_features].values.astype(float) # type: ignore
y_val = val_df[label_feature].values.astype(float) # type: ignore
t_val = val_df[treatment_feature].values.astype(float) # type: ignore

# %%
# Transform to tensor
def to_tensor(arr):
    return torch.tensor(arr, dtype=torch.float32)

x_men_train_t = to_tensor(X_train)
x_men_val_t = to_tensor(X_val)
x_men_test_t = to_tensor(X_test)

y_men_train_t = to_tensor(y_train).reshape(-1, 1)
y_men_val_t = to_tensor(y_val).reshape(-1, 1)
y_men_test_t = to_tensor(y_test).reshape(-1, 1)

# t_train/t_val/t_test cũng tương tự
t_men_train_t = to_tensor(t_train.astype(float)).reshape(-1, 1)
t_men_val_t = to_tensor(t_val.astype(float)).reshape(-1, 1)
t_men_test_t = to_tensor(t_test.astype(float)).reshape(-1, 1)

# Data loader
train_dataset = TensorDataset(x_men_train_t, t_men_train_t, y_men_train_t)
val_dataset = TensorDataset(x_men_val_t, t_men_val_t, y_men_val_t)
test_dataset = TensorDataset(x_men_test_t, t_men_test_t, y_men_test_t)

batch_size = 6400
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory = True)

print("-------------------------------------------------------------")
print("✅ Completed transform to tensor ✅")
print(f"Shape of train: x={x_men_train_t.shape}; y={y_men_train_t.shape}; t={t_men_train_t.shape}")
print(f"Shape of val: x={x_men_val_t.shape}; y={y_men_val_t.shape}; t={t_men_val_t.shape}")
print(f"Shape of test: x={x_men_test_t.shape}; y={y_men_test_t.shape}; t={t_men_test_t.shape}")
# Out:
# -------------------------------------------------------------
# ✅ Completed transform to tensor ✅
# Shape of train: x=torch.Size([25567, 10]); y=torch.Size([25567, 1]); t=torch.Size([25567, 1])
# Shape of val: x=torch.Size([4262, 10]); y=torch.Size([4262, 1]); t=torch.Size([4262, 1])
# Shape of test: x=torch.Size([12784, 10]); y=torch.Size([12784, 1]); t=torch.Size([12784, 1])

# %%
dict_conv_models = {}

# %%
epochs = 150
activation = torch.nn.ReLU

# %%
seed_everything(42)
tarnet = Tarnet(
        input_dim=x_men_train_t.shape[1], epochs=epochs, learning_rate=5e-4, 
        weight_decay=1e-5, use_ema=True, ema_alpha=0.15, patience=20,
        shared_hidden=200, outcome_hidden=100,
        outcome_droupout=0.1, shared_dropout=0,
        early_stop_metric="qini", early_stop_start_epoch=30,
        activation=activation
    )
tarnet.fit(train_loader, val_loader)
y0_pred, y1_pred = tarnet.predict(x_men_test_t)
uplift_pred_tarnet = (y1_pred - y0_pred).detach().cpu().numpy().flatten()

auuc_tarnet = auuc(y_true=y_test.flatten(), t_true=t_test.flatten(), uplift_pred=uplift_pred_tarnet, bins=100)
print(f"TARNet AUUC: {auuc_tarnet:.6f}")
# Out:
# Locked random seed: 42
# 🔃🔃🔃Begin training Tarnet🔃🔃🔃
# 📊 Early Stop Metric: QINI
# 📊 Early Stop Start Epoch: 31
# 📊 Strategy: Two-Stage EMA Filter (alpha=0.15)
#    EMA filters noise spikes, Raw Qini determines peak height
#    Select checkpoint: raw_qini is highest AND raw_qini >= ema_qini
# Epoch 1/150 | Loss: 1.3866 | Val Loss: 1.3692 | Val Qini: 0.5549 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.5549 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 2/150 | Loss: 1.3011 | Val Loss: 1.2704 | Val Qini: 0.6578 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.5703 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 3/150 | Loss: 1.1388 | Val Loss: 1.0741 | Val Qini: 0.7109 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.5914 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 4/150 | Loss: 0.8279 | Val Loss: 0.7218 | Val Qini: 0.7241 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.6113 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 5/150 | Loss: 0.4151 | Val Loss: 0.3178 | Val Qini: 0.2356 (patience: 1/20)EMA Trend: 0.5550 | (patience: 1/20)
# Epoch 6/150 | Loss: 0.1370 | Val Loss: 0.1247 | Val Qini: 0.2638 (patience: 2/20)EMA Trend: 0.5113 | (patience: 2/20)
# Epoch 7/150 | Loss: 0.1109 | Val Loss: 0.1277 | Val Qini: 0.2713 (patience: 3/20)EMA Trend: 0.4753 | (patience: 3/20)
# Epoch 8/150 | Loss: 0.1395 | Val Loss: 0.1578 | Val Qini: 0.2851 (patience: 4/20)EMA Trend: 0.4468 | (patience: 4/20)
# Epoch 9/150 | Loss: 0.1431 | Val Loss: 0.1648 | Val Qini: 0.3044 (patience: 5/20)EMA Trend: 0.4254 | (patience: 5/20)
# Epoch 10/150 | Loss: 0.1476 | Val Loss: 0.1525 | Val Qini: 0.3236 (patience: 6/20)EMA Trend: 0.4101 | (patience: 6/20)
# Epoch 11/150 | Loss: 0.1348 | Val Loss: 0.1325 | Val Qini: 0.3547 (patience: 7/20)EMA Trend: 0.4018 | (patience: 7/20)
# Epoch 12/150 | Loss: 0.1028 | Val Loss: 0.1148 | Val Qini: 0.3941 (patience: 8/20)EMA Trend: 0.4007 | (patience: 8/20)
# Epoch 13/150 | Loss: 0.1121 | Val Loss: 0.1066 | Val Qini: 0.4312 ✓ above trend but not peak (patience: 9/20)EMA Trend: 0.4052 | ✓ above trend but not peak (patience: 9/20)
# Epoch 14/150 | Loss: 0.0838 | Val Loss: 0.1069 | Val Qini: 0.4653 ✓ above trend but not peak (patience: 10/20)EMA Trend: 0.4143 | ✓ above trend but not peak (patience: 10/20)
# Epoch 15/150 | Loss: 0.1105 | Val Loss: 0.1082 | Val Qini: 0.5022 ✓ above trend but not peak (patience: 11/20)EMA Trend: 0.4274 | ✓ above trend but not peak (patience: 11/20)
# Epoch 16/150 | Loss: 0.1148 | Val Loss: 0.1063 | Val Qini: 0.5247 ✓ above trend but not peak (patience: 12/20)EMA Trend: 0.4420 | ✓ above trend but not peak (patience: 12/20)
# Epoch 17/150 | Loss: 0.1092 | Val Loss: 0.1040 | Val Qini: 0.5428 ✓ above trend but not peak (patience: 13/20)EMA Trend: 0.4572 | ✓ above trend but not peak (patience: 13/20)
# Epoch 18/150 | Loss: 0.1056 | Val Loss: 0.1034 | Val Qini: 0.5597 ✓ above trend but not peak (patience: 14/20)EMA Trend: 0.4725 | ✓ above trend but not peak (patience: 14/20)
# Epoch 19/150 | Loss: 0.1227 | Val Loss: 0.1039 | Val Qini: 0.5713 ✓ above trend but not peak (patience: 15/20)EMA Trend: 0.4874 | ✓ above trend but not peak (patience: 15/20)
# Epoch 20/150 | Loss: 0.0973 | Val Loss: 0.1039 | Val Qini: 0.5788 ✓ above trend but not peak (patience: 16/20)EMA Trend: 0.5011 | ✓ above trend but not peak (patience: 16/20)
# Epoch 21/150 | Loss: 0.1004 | Val Loss: 0.1034 | Val Qini: 0.5918 ✓ above trend but not peak (patience: 17/20)EMA Trend: 0.5147 | ✓ above trend but not peak (patience: 17/20)
# Epoch 22/150 | Loss: 0.1020 | Val Loss: 0.1029 | Val Qini: 0.6057 ✓ above trend but not peak (patience: 18/20)EMA Trend: 0.5283 | ✓ above trend but not peak (patience: 18/20)
# Epoch 23/150 | Loss: 0.0973 | Val Loss: 0.1026 | Val Qini: 0.6140 ✓ above trend but not peak (patience: 19/20)EMA Trend: 0.5412 | ✓ above trend but not peak (patience: 19/20)
# Epoch 24/150 | Loss: 0.0990 | Val Loss: 0.1026 | Val Qini: 0.6200 ✓ above trend but not peak (patience: 20/20)EMA Trend: 0.5530 | ✓ above trend but not peak (patience: 20/20)
# Epoch 25/150 | Loss: 0.0972 | Val Loss: 0.1025 | Val Qini: 0.6226 ✓ above trend but not peak (patience: 21/20)EMA Trend: 0.5634 | ✓ above trend but not peak (patience: 21/20)
# Epoch 26/150 | Loss: 0.1000 | Val Loss: 0.1025 | Val Qini: 0.6244 ✓ above trend but not peak (patience: 22/20)EMA Trend: 0.5726 | ✓ above trend but not peak (patience: 22/20)
# Epoch 27/150 | Loss: 0.0988 | Val Loss: 0.1025 | Val Qini: 0.6263 ✓ above trend but not peak (patience: 23/20)EMA Trend: 0.5806 | ✓ above trend but not peak (patience: 23/20)
# Epoch 28/150 | Loss: 0.1112 | Val Loss: 0.1025 | Val Qini: 0.6259 ✓ above trend but not peak (patience: 24/20)EMA Trend: 0.5874 | ✓ above trend but not peak (patience: 24/20)
# Epoch 29/150 | Loss: 0.1065 | Val Loss: 0.1024 | Val Qini: 0.6319 ✓ above trend but not peak (patience: 25/20)EMA Trend: 0.5941 | ✓ above trend but not peak (patience: 25/20)
# Epoch 30/150 | Loss: 0.1066 | Val Loss: 0.1023 | Val Qini: 0.6332 ✓ above trend but not peak (patience: 26/20)EMA Trend: 0.6000 | ✓ above trend but not peak (patience: 26/20)
# Epoch 31/150 | Loss: 0.1058 | Val Loss: 0.1023 | Val Qini: 0.6317 ✓ above trend but not peak (patience: 27/20)EMA Trend: 0.6047 | ✓ above trend but not peak (patience: 27/20)
#
# 🛑 Early stopping triggered at epoch 31!
#    No valid peak (raw ≥ trend) found in last 20 epochs
#
# ✅ Training completed! Restored model to epoch 4
#    Best Raw Qini: 0.7241
#    Final EMA Trend: 0.6047
#    Strategy: Selected highest peak that stayed above EMA trend
# TARNet AUUC: 0.558203

# %%
seed_everything(42)
dragonnet = Dragonnet(
    input_dim=x_men_train_t.shape[1], epochs=epochs, learning_rate=1e-4, 
    alpha=0.1, beta=0.5,
    weight_decay=1e-5, ema_alpha=0.35, patience=20,
    shared_hidden=200, outcome_hidden=100,
    outcome_droupout=0, shared_dropout=0,
    early_stop_metric="qini", early_stop_start_epoch=30,
    use_ema= True,
    activation=activation
    )
dragonnet.fit(train_loader, val_loader)
y0_pred, y1_pred,_,_ = dragonnet.predict(x_men_test_t)
uplift_pred_dragonnet = (y1_pred - y0_pred).detach().cpu().numpy().flatten()
# Out:
# Locked random seed: 42
# 🔃🔃🔃Begin training Dragonnet🔃🔃🔃
# 📊 Early Stop Metric: QINI
# 📊 Early Stop Start Epoch: 31
# 📊 Strategy: Two-Stage EMA Filter (alpha=0.35)
#    EMA filters noise spikes, Raw Qini determines peak height
#    Select checkpoint: raw_qini is highest AND raw_qini >= ema_qini
# Epoch 1/150 | Base Loss: 1.5261 | Tarreg Loss: 0.508266 | Total Loss: 2.0344 | Val Loss: 1.5229 | Raw Qini: 0.6641 | EMA Trend: 0.6641 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 2/150 | Base Loss: 1.5127 | Tarreg Loss: 0.489961 | Total Loss: 2.0027 | Val Loss: 1.5092 | Raw Qini: 0.6719 | EMA Trend: 0.6668 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 3/150 | Base Loss: 1.4982 | Tarreg Loss: 0.485512 | Total Loss: 1.9837 | Val Loss: 1.4945 | Raw Qini: 0.7009 | EMA Trend: 0.6787 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 4/150 | Base Loss: 1.4823 | Tarreg Loss: 0.483622 | Total Loss: 1.9659 | Val Loss: 1.4778 | Raw Qini: 0.7074 | EMA Trend: 0.6888 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 5/150 | Base Loss: 1.4634 | Tarreg Loss: 0.473439 | Total Loss: 1.9369 | Val Loss: 1.4584 | Raw Qini: 0.7117 | EMA Trend: 0.6968 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 6/150 | Base Loss: 1.4414 | Tarreg Loss: 0.474161 | Total Loss: 1.9155 | Val Loss: 1.4355 | Raw Qini: 0.7411 | EMA Trend: 0.7123 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 7/150 | Base Loss: 1.4159 | Tarreg Loss: 0.465905 | Total Loss: 1.8818 | Val Loss: 1.4086 | Raw Qini: 0.7468 | EMA Trend: 0.7244 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 8/150 | Base Loss: 1.3858 | Tarreg Loss: 0.463173 | Total Loss: 1.8490 | Val Loss: 1.3770 | Raw Qini: 0.7527 | EMA Trend: 0.7343 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 9/150 | Base Loss: 1.3498 | Tarreg Loss: 0.461551 | Total Loss: 1.8113 | Val Loss: 1.3390 | Raw Qini: 0.7522 | EMA Trend: 0.7406 | ✓ above trend but not peak (patience: 1/20)
# Epoch 10/150 | Base Loss: 1.3055 | Tarreg Loss: 0.462457 | Total Loss: 1.7679 | Val Loss: 1.2934 | Raw Qini: 0.7480 | EMA Trend: 0.7432 | ✓ above trend but not peak (patience: 2/20)
# Epoch 11/150 | Base Loss: 1.2533 | Tarreg Loss: 0.464355 | Total Loss: 1.7176 | Val Loss: 1.2383 | Raw Qini: 0.7463 | EMA Trend: 0.7442 | ✓ above trend but not peak (patience: 3/20)
# Epoch 12/150 | Base Loss: 1.1904 | Tarreg Loss: 0.456585 | Total Loss: 1.6470 | Val Loss: 1.1718 | Raw Qini: 0.7391 | EMA Trend: 0.7424 | (patience: 4/20)
# Epoch 13/150 | Base Loss: 1.1138 | Tarreg Loss: 0.458187 | Total Loss: 1.5719 | Val Loss: 1.0918 | Raw Qini: 0.7262 | EMA Trend: 0.7367 | (patience: 5/20)
# Epoch 14/150 | Base Loss: 1.0234 | Tarreg Loss: 0.453981 | Total Loss: 1.4774 | Val Loss: 0.9969 | Raw Qini: 0.7216 | EMA Trend: 0.7315 | (patience: 6/20)
# Epoch 15/150 | Base Loss: 0.9181 | Tarreg Loss: 0.447234 | Total Loss: 1.3653 | Val Loss: 0.8885 | Raw Qini: 0.7157 | EMA Trend: 0.7259 | (patience: 7/20)
# Epoch 16/150 | Base Loss: 0.8019 | Tarreg Loss: 0.441833 | Total Loss: 1.2437 | Val Loss: 0.7699 | Raw Qini: 0.7117 | EMA Trend: 0.7209 | (patience: 8/20)
# Epoch 17/150 | Base Loss: 0.6824 | Tarreg Loss: 0.437238 | Total Loss: 1.1196 | Val Loss: 0.6473 | Raw Qini: 0.6506 | EMA Trend: 0.6963 | (patience: 9/20)
# Epoch 18/150 | Base Loss: 0.5556 | Tarreg Loss: 0.422917 | Total Loss: 0.9785 | Val Loss: 0.5282 | Raw Qini: 0.4132 | EMA Trend: 0.5973 | (patience: 10/20)
# Epoch 19/150 | Base Loss: 0.4485 | Tarreg Loss: 0.413267 | Total Loss: 0.8617 | Val Loss: 0.4209 | Raw Qini: 0.2902 | EMA Trend: 0.4898 | (patience: 11/20)
# Epoch 20/150 | Base Loss: 0.3552 | Tarreg Loss: 0.399739 | Total Loss: 0.7550 | Val Loss: 0.3323 | Raw Qini: 0.3008 | EMA Trend: 0.4236 | (patience: 12/20)
# Epoch 21/150 | Base Loss: 0.2916 | Tarreg Loss: 0.387979 | Total Loss: 0.6796 | Val Loss: 0.2661 | Raw Qini: 0.2954 | EMA Trend: 0.3788 | (patience: 13/20)
# Epoch 22/150 | Base Loss: 0.2281 | Tarreg Loss: 0.380414 | Total Loss: 0.6085 | Val Loss: 0.2225 | Raw Qini: 0.2957 | EMA Trend: 0.3497 | (patience: 14/20)
# Epoch 23/150 | Base Loss: 0.2052 | Tarreg Loss: 0.371702 | Total Loss: 0.5769 | Val Loss: 0.1973 | Raw Qini: 0.2954 | EMA Trend: 0.3307 | (patience: 15/20)
# Epoch 24/150 | Base Loss: 0.1917 | Tarreg Loss: 0.366847 | Total Loss: 0.5585 | Val Loss: 0.1850 | Raw Qini: 0.3017 | EMA Trend: 0.3205 | (patience: 16/20)
# Epoch 25/150 | Base Loss: 0.1893 | Tarreg Loss: 0.361999 | Total Loss: 0.5513 | Val Loss: 0.1801 | Raw Qini: 0.3063 | EMA Trend: 0.3155 | (patience: 17/20)
# Epoch 26/150 | Base Loss: 0.1738 | Tarreg Loss: 0.359599 | Total Loss: 0.5334 | Val Loss: 0.1788 | Raw Qini: 0.3088 | EMA Trend: 0.3132 | (patience: 18/20)
# Epoch 27/150 | Base Loss: 0.1807 | Tarreg Loss: 0.356096 | Total Loss: 0.5368 | Val Loss: 0.1789 | Raw Qini: 0.3174 | EMA Trend: 0.3147 | ✓ above trend but not peak (patience: 19/20)
# Epoch 28/150 | Base Loss: 0.1658 | Tarreg Loss: 0.354979 | Total Loss: 0.5208 | Val Loss: 0.1793 | Raw Qini: 0.3186 | EMA Trend: 0.3160 | ✓ above trend but not peak (patience: 20/20)
# Epoch 29/150 | Base Loss: 0.1981 | Tarreg Loss: 0.352578 | Total Loss: 0.5507 | Val Loss: 0.1796 | Raw Qini: 0.3248 | EMA Trend: 0.3191 | ✓ above trend but not peak (patience: 21/20)
# Epoch 30/150 | Base Loss: 0.1821 | Tarreg Loss: 0.350216 | Total Loss: 0.5324 | Val Loss: 0.1795 | Raw Qini: 0.3317 | EMA Trend: 0.3235 | ✓ above trend but not peak (patience: 22/20)
# Epoch 31/150 | Base Loss: 0.1866 | Tarreg Loss: 0.347216 | Total Loss: 0.5339 | Val Loss: 0.1793 | Raw Qini: 0.3400 | EMA Trend: 0.3293 | ✓ above trend but not peak (patience: 23/20)
#
# 🛑 Early stopping triggered at epoch 31!
#    No valid peak (raw ≥ trend) found in last 20 epochs
#
# ✅ Training completed! Restored model to epoch 8
#    Best Raw Qini: 0.7527
#    Final EMA Trend: 0.3293
#    Strategy: Selected highest peak that stayed above EMA trend
# /home/ducvu0904/Documents/Lab/Conversion vs revenue benchmarking/Conversion/Dragonnet/dragonnet.py:329: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.float32, device=self.device)

# %%
seed_everything(42)
cfr = Cfrnet(
    input_dim=x_men_train_t.shape[1],
    epochs=epochs,
    alpha=1.0,
    learning_rate=1e-3,
    weight_decay=1e-5,
    method="mmd_rbf",
    ema_alpha=0.35, patience=20,
    shared_hidden=200, outcome_hidden=100,
    outcome_dropout=0, shared_dropout=0,
    early_stop_metric="qini", early_stop_start_epoch=30,
    use_ema= True,
    activation=activation
    )
cfr.fit(train_loader, val_loader)
y0_pred, y1_pred = cfr.predict(x_men_test_t)
uplift_pred_cfr = (y1_pred - y0_pred).detach().cpu().numpy().flatten()
# Out:
# Locked random seed: 42
# 🔃🔃🔃Begin training Dragonnet🔃🔃🔃
# 📊 Early Stop Metric: QINI
# 📊 Early Stop Start Epoch: 31
# 📊 Strategy: Two-Stage EMA Filter (alpha=0.35)
#    EMA filters noise spikes, Raw Qini determines peak height
#    Select checkpoint: raw_qini is highest AND raw_qini >= ema_qini
# Epoch 1/150 | Loss: -7.5261 | Val Loss: -7.5502 | Val Qini: 0.3241 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.3241 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 2/150 | Loss: -7.6775 | Val Loss: -7.7435 | Val Qini: 0.2774 (patience: 1/20)EMA Trend: 0.3078 | (patience: 1/20)
# Epoch 3/150 | Loss: -7.9330 | Val Loss: -7.9628 | Val Qini: 0.7398 ⭐ NEW BEST (peak ≥ trend)EMA Trend: 0.4590 | ⭐ NEW BEST (peak ≥ trend)
# Epoch 4/150 | Loss: -7.9836 | Val Loss: -7.9819 | Val Qini: 0.7330 ✓ above trend but not peak (patience: 1/20)EMA Trend: 0.5549 | ✓ above trend but not peak (patience: 1/20)
# Epoch 5/150 | Loss: -7.9793 | Val Loss: -7.9819 | Val Qini: 0.7257 ✓ above trend but not peak (patience: 2/20)EMA Trend: 0.6147 | ✓ above trend but not peak (patience: 2/20)
# Epoch 6/150 | Loss: -7.9872 | Val Loss: -7.9819 | Val Qini: 0.7205 ✓ above trend but not peak (patience: 3/20)EMA Trend: 0.6517 | ✓ above trend but not peak (patience: 3/20)
# Epoch 7/150 | Loss: -7.9829 | Val Loss: -7.9819 | Val Qini: 0.7147 ✓ above trend but not peak (patience: 4/20)EMA Trend: 0.6738 | ✓ above trend but not peak (patience: 4/20)
# Epoch 8/150 | Loss: -7.9838 | Val Loss: -7.9819 | Val Qini: 0.7095 ✓ above trend but not peak (patience: 5/20)EMA Trend: 0.6863 | ✓ above trend but not peak (patience: 5/20)
# Epoch 9/150 | Loss: -7.9841 | Val Loss: -7.9819 | Val Qini: 0.7086 ✓ above trend but not peak (patience: 6/20)EMA Trend: 0.6941 | ✓ above trend but not peak (patience: 6/20)
# Epoch 10/150 | Loss: -7.9818 | Val Loss: -7.9819 | Val Qini: 0.7054 ✓ above trend but not peak (patience: 7/20)EMA Trend: 0.6980 | ✓ above trend but not peak (patience: 7/20)
# Epoch 11/150 | Loss: -7.9826 | Val Loss: -7.9818 | Val Qini: 0.7047 ✓ above trend but not peak (patience: 8/20)EMA Trend: 0.7004 | ✓ above trend but not peak (patience: 8/20)
# Epoch 12/150 | Loss: -7.9833 | Val Loss: -7.9818 | Val Qini: 0.7022 ✓ above trend but not peak (patience: 9/20)EMA Trend: 0.7010 | ✓ above trend but not peak (patience: 9/20)
# Epoch 13/150 | Loss: -7.9816 | Val Loss: -7.9818 | Val Qini: 0.7024 ✓ above trend but not peak (patience: 10/20)EMA Trend: 0.7015 | ✓ above trend but not peak (patience: 10/20)
# Epoch 14/150 | Loss: -7.9875 | Val Loss: -7.9818 | Val Qini: 0.7019 ✓ above trend but not peak (patience: 11/20)EMA Trend: 0.7017 | ✓ above trend but not peak (patience: 11/20)
# Epoch 15/150 | Loss: -7.9812 | Val Loss: -7.9818 | Val Qini: 0.7027 ✓ above trend but not peak (patience: 12/20)EMA Trend: 0.7020 | ✓ above trend but not peak (patience: 12/20)
# Epoch 16/150 | Loss: -7.9796 | Val Loss: -7.9818 | Val Qini: 0.7060 ✓ above trend but not peak (patience: 13/20)EMA Trend: 0.7034 | ✓ above trend but not peak (patience: 13/20)
# Epoch 17/150 | Loss: -7.9816 | Val Loss: -7.9818 | Val Qini: 0.7081 ✓ above trend but not peak (patience: 14/20)EMA Trend: 0.7050 | ✓ above trend but not peak (patience: 14/20)
# Epoch 18/150 | Loss: -7.9815 | Val Loss: -7.9818 | Val Qini: 0.7081 ✓ above trend but not peak (patience: 15/20)EMA Trend: 0.7061 | ✓ above trend but not peak (patience: 15/20)
# Epoch 19/150 | Loss: -7.9784 | Val Loss: -7.9817 | Val Qini: 0.7106 ✓ above trend but not peak (patience: 16/20)EMA Trend: 0.7077 | ✓ above trend but not peak (patience: 16/20)
# Epoch 20/150 | Loss: -7.9833 | Val Loss: -7.9817 | Val Qini: 0.7126 ✓ above trend but not peak (patience: 17/20)EMA Trend: 0.7094 | ✓ above trend but not peak (patience: 17/20)
# Epoch 21/150 | Loss: -7.9830 | Val Loss: -7.9817 | Val Qini: 0.7130 ✓ above trend but not peak (patience: 18/20)EMA Trend: 0.7106 | ✓ above trend but not peak (patience: 18/20)
# Epoch 22/150 | Loss: -7.9826 | Val Loss: -7.9817 | Val Qini: 0.7136 ✓ above trend but not peak (patience: 19/20)EMA Trend: 0.7117 | ✓ above trend but not peak (patience: 19/20)
# Epoch 23/150 | Loss: -7.9830 | Val Loss: -7.9817 | Val Qini: 0.7132 ✓ above trend but not peak (patience: 20/20)EMA Trend: 0.7122 | ✓ above trend but not peak (patience: 20/20)
# Epoch 24/150 | Loss: -7.9827 | Val Loss: -7.9817 | Val Qini: 0.7153 ✓ above trend but not peak (patience: 21/20)EMA Trend: 0.7133 | ✓ above trend but not peak (patience: 21/20)
# Epoch 25/150 | Loss: -7.9844 | Val Loss: -7.9817 | Val Qini: 0.7145 ✓ above trend but not peak (patience: 22/20)EMA Trend: 0.7137 | ✓ above trend but not peak (patience: 22/20)
# Epoch 26/150 | Loss: -7.9827 | Val Loss: -7.9817 | Val Qini: 0.7119 (patience: 23/20)EMA Trend: 0.7131 | (patience: 23/20)
# Epoch 27/150 | Loss: -7.9822 | Val Loss: -7.9817 | Val Qini: 0.7081 (patience: 24/20)EMA Trend: 0.7113 | (patience: 24/20)
# Epoch 28/150 | Loss: -7.9810 | Val Loss: -7.9817 | Val Qini: 0.7107 (patience: 25/20)EMA Trend: 0.7111 | (patience: 25/20)
# Epoch 29/150 | Loss: -7.9806 | Val Loss: -7.9817 | Val Qini: 0.7072 (patience: 26/20)EMA Trend: 0.7097 | (patience: 26/20)
# Epoch 30/150 | Loss: -7.9815 | Val Loss: -7.9817 | Val Qini: 0.7058 (patience: 27/20)EMA Trend: 0.7084 | (patience: 27/20)
# Epoch 31/150 | Loss: -7.9817 | Val Loss: -7.9817 | Val Qini: 0.7014 (patience: 28/20)EMA Trend: 0.7059 | (patience: 28/20)
#
# 🛑 Early stopping triggered at epoch 31!
#    No valid peak (raw ≥ trend) found in last 20 epochs
#
# ✅ Training completed! Restored model to epoch 3
#    Best Raw Qini: 0.7398
#    Final EMA Trend: 0.7059
#    Strategy: Selected highest peak that stayed above EMA trend
# /home/ducvu0904/Documents/Lab/Conversion vs revenue benchmarking/Conversion/CFRnet/cfrnet.py:275: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.float32, device=self.device)

# %%
seed_everything(42)
base_model = LGBMClassifier(
    n_estimators=145,            
    learning_rate=0.001404291039,
    max_depth=5,
    num_leaves=12,
    min_child_samples=11,
    subsample=0.9040497977,
    colsample_bytree=0.5790428319,
    random_state=42,
    n_jobs=-1
)
s_learner = SoloModel(estimator=base_model)
        
s_learner.fit(X=X_train, y=y_train, treatment=t_train)
uplift_pred_s_learner = s_learner.predict(X_test)

auqc_s_learner = auqc(y_true=y_test.flatten(), t_true=t_test.flatten(), uplift_pred=uplift_pred_s_learner.flatten(), bins=100)
print(f"S-Learner (LGBM) AUQC: {auqc_s_learner:.6f}")
# Out:
# Locked random seed: 42
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# S-Learner (LGBM) AUQC: 0.593847

# %%
from Conversion.CausalForest.cf_hill import CausalForestWrapper
cf_model = CausalForestWrapper(
            task_type='conversion', 
            random_state=42, 
            n_estimators=444,
            max_depth=9,
            min_samples_split=181,
            min_samples_leaf=29
)
cf_model.fit(X_train, y_train.flatten(), t_train.flatten())
uplift_pred_cf = cf_model.predict(X_test)

auqc_cf = auqc(y_true=y_test.flatten(), t_true=t_test.flatten(), uplift_pred=uplift_pred_cf.flatten(), bins=100)
print(f"Causal Forest AUQC: {auqc_cf:.6f}")
# Out:
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# Causal Forest AUQC: 0.489849

# %%
seed_everything(42)
params = {
    'n_estimators': 373,            
    'learning_rate': 6.03E-03,
    'max_depth': 12,
    'num_leaves': 137,
    'min_child_samples': 166,
    'subsample': 9.67E-01,
    'colsample_bytree': 5.38E-01,
    'n_jobs': -1
}
model_trmnt = LGBMClassifier(**params, random_state=42, verbose=-1)
model_ctrl = LGBMClassifier(**params, random_state=42, verbose=-1)

# TwoModels expects 1D targets and treatment arrays.
y_train_1d = y_train.ravel()
t_train_1d = t_train.ravel().astype(int)

# Bọc vào TwoModels (T-Learner)
t_learner = TwoModels(estimator_trmnt=model_trmnt, estimator_ctrl=model_ctrl, method='vanilla')

# Huấn luyện mô hình
t_learner.fit(X=X_train, y=y_train_1d, treatment=t_train_1d)

# Dự đoán uplift trên tập test
uplift_pred_t_learner = t_learner.predict(X_test)

auqc_t_learner = auqc(y_true=y_test.flatten(), t_true=t_test.flatten(), uplift_pred=uplift_pred_t_learner.flatten(), bins=100)
print(f"T-Learner (LGBM) AUQC: {auqc_t_learner:.6f}")
# Out:
# Locked random seed: 42
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# T-Learner (LGBM) AUQC: 0.578960

# %%
from pathlib import Path
import sys

# Add Conversion/R-Learner to import path
rlearner_dir = Path.cwd().parents[1] / "Conversion" / "R-Learner"
if str(rlearner_dir) not in sys.path:
    sys.path.append(str(rlearner_dir))

from rlearner_hill import get_rlearner_conversion
seed_everything(42)

# Match benchmark input format: 1D int arrays for conversion/treatment
y_train_rl = y_train.ravel().astype(int)
t_train_rl = t_train.ravel().astype(int)
y_test_rl = y_test.ravel().astype(int)
t_test_rl = t_test.ravel().astype(int)

# Khoi tao R-Learner cho Conversion
params = {
    'n_estimators': 459,
    'learning_rate': 8.83E-02,
    'max_depth': 12,
    'num_leaves': 81,
    'min_child_samples': 181,
    'subsample': 6.77E-01,
    'colsample_bytree': 8.67E-01,
    'n_jobs': -1
}
r_learner_model = get_rlearner_conversion(params, 42)

# Huan luyen mo hinh
r_learner_model.fit(Y=y_train_rl, T=t_train_rl, X=X_train)

# Du doan uplift tren tap test de so sanh cong bang voi cac model khac
uplift_pred_r_learner = r_learner_model.effect(X_test).flatten()
auqc_r_learner = auqc(y_true=y_test_rl, t_true=t_test_rl, uplift_pred=uplift_pred_r_learner, bins=100)
print(f"R-Learner AUQC: {auqc_r_learner:.6f}")
# Out:
# Locked random seed: 42
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# R-Learner AUQC: 0.590459

# %%
from pathlib import Path
import sys
import importlib

# Add Conversion/X-Learner to import path
xlearner_dir = Path.cwd().parents[1] / "Conversion" / "X-Learner"
if str(xlearner_dir) not in sys.path:
    sys.path.append(str(xlearner_dir))

import xlearner_hill
importlib.reload(xlearner_hill)
getxlearner = xlearner_hill.get_xlearner

params = {
    'n_estimators': 111,
    'learning_rate': 1.03E-03,
    'max_depth': 12,
    'num_leaves': 92,
    'min_child_samples': 57,
    'subsample': 5.62E-01,
    'colsample_bytree': 5.22E-01,
    'n_jobs': -1
}

SEED = 42
seed_everything(SEED)
x_learner_model = getxlearner("conversion", params, seed=SEED)
x_learner_model.fit(Y=y_train.ravel().astype(int), T=t_train.ravel().astype(int), X=X_train)
uplift_pred_x = x_learner_model.effect(X_test).flatten()

auqc_x_learner = auqc(y_true=y_test.ravel().astype(int), t_true=t_test.ravel().astype(int), uplift_pred=uplift_pred_x, bins=100)
print(f"X-Learner AUQC (seed={SEED}): {auqc_x_learner:.6f}")
# Out:
# Locked random seed: 42
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/ducvu0904/miniconda3/envs/ai/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# X-Learner AUQC (seed=42): 0.518500

# %%
y_true = y_men_test_t.cpu().numpy().flatten()
t_true = t_men_test_t.cpu().numpy().flatten()

# %%
# Định nghĩa bảng màu cố định cho các model phổ biến
MODEL_COLORS = {
    'tarnet': '#1f77b4',       # Blue
    'cfrnet': '#ff7f0e',       # Orange
    'dragonnet': '#2ca02c',    # Green
    's-learner': '#d62728',    # Red
    't-learner': '#9467bd',    # Purple
    'r-learner': '#8c564b',    # Brown
    'causalforest': '#e377c2', # Pink
    'x-learner': '#17becf',    # Cyan
    'random': '#7f7f7f'        # Gray (cho đường random)
}

# %%
def auqc_core(y_true, t_true, uplift_pred, bins=100):
    """
    Hàm này CHÍNH LÀ hàm gốc của bạn, không đổi một dấu phẩy ở logic toán,
    chỉ bỏ phần plot đi để trả về dữ liệu vẽ.
    """
    y_true = np.array(y_true).flatten()
    t_true = np.array(t_true).flatten()
    uplift_pred = np.array(uplift_pred).flatten()

    data = pd.DataFrame({'y': y_true, "t": t_true, "pred": uplift_pred})
    # Thêm kind='mergesort' để đảm bảo sort luôn nhất quán
    data = data.sort_values(by="pred", ascending=False, kind='mergesort').reset_index(drop=True)
    
    try:
        data["bucket"] = pd.qcut(-data['pred'], bins, labels=False, duplicates="drop")
    except:
        data['bucket'] = pd.cut(-data['pred'], bins, labels=False)
    
    cumulative_gain = []
    population = []
    bucket_ids = sorted(data['bucket'].unique())
    
    for bucket_id in bucket_ids:
        cumulative_data = data.loc[data['bucket'] <= bucket_id]
        
        control_group = cumulative_data.loc[cumulative_data['t']==0]
        treatment_group =  cumulative_data.loc[cumulative_data['t']==1]
        
        n_control = len(control_group)
        n_treatment = len(treatment_group)
        n_total = n_control + n_treatment
        
        if n_control==0 or n_total==0:
            continue
        
        sum_y_control = control_group['y'].sum()
        sum_y_treatment = treatment_group['y'].sum()
        qini_gain = sum_y_treatment - sum_y_control * (n_treatment/n_control)
        
        cumulative_gain.append(qini_gain)
        population.append(n_total)
        
    if len(cumulative_gain) == 0:
        return np.array([0]), np.array([0]), 0.0, np.array([0])
    
    gap0 = cumulative_gain[-1]
    norm_factor = abs(gap0) if abs(gap0) > 1e-9 else 1.0
    cumulative_gains_norm = [x / norm_factor for x in cumulative_gain]
    
    pop_max = max(population)
    pop_fraction = [p/pop_max for p in population]
    
    x_curve = np.append(0, pop_fraction)
    y_curve = np.append(0, cumulative_gains_norm)
    y_rand = x_curve * y_curve[-1]
    
    qini_score = np.trapezoid(y_curve, x_curve)
    
    # Trả về các tham số để plot
    return x_curve, y_curve, qini_score, y_rand

# ==========================================
# HÀM VẼ (DÙNG CORE CỦA BẠN)
# ==========================================
import matplotlib.pyplot as plt
import matplotlib.cm as cm # Thêm thư viện này để lấy bảng màu

def plot_compare_auqc(dict_preds, y_true, t_true, bins=100):
    plt.figure(figsize=(15, 10), facecolor='#ffffff')
    
    random_plotted = False
    
    for name, preds in dict_preds.items():
        # Chuẩn hóa tên để lấy màu (ví dụ: "TARNet" -> "tarnet")
        name_lower = name.lower().replace(" ", "")
        color = MODEL_COLORS.get(name_lower, '#333333') # Màu mặc định là xám đậm nếu ko tìm thấy
        
        # GỌI HÀM CORE
        x_c, y_c, score, y_r = auqc_core(y_true, t_true, preds, bins)
        
        plt.plot(x_c, y_c, lw=2.5, label=f"{name}" , color=color)
        
        # Vẽ đường Random
        if not random_plotted:
            rand_score = np.trapezoid(y_r, x_c)
            plt.plot(x_c, y_r, color=MODEL_COLORS['random'], linestyle='--', lw=1.5, label='Random')
            random_plotted = True

    plt.title("Uplift Model Comparison", fontsize=14, fontweight='bold')
    plt.xlabel("Population Targeted (Fraction)")
    plt.ylabel("Normalized Qini Gain")
    
    # Đẩy Legend ra ngoài để không che đường biểu đồ
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    
    plt.grid(True, linestyle=':', alpha=0.5)
    plt.tight_layout()
    plt.show()

# --- SỬ DỤNG ---
dict_all_models = {
    'TARNet': uplift_pred_tarnet,
    'CFRNet': uplift_pred_cfr,
    'Dragonnet': uplift_pred_dragonnet,
    'S-Learner': uplift_pred_s_learner,
    'T-Learner': uplift_pred_t_learner,
    'R-Learner': uplift_pred_r_learner,
    'CausalForest': uplift_pred_cf,
    'X-Learner': uplift_pred_x
}

plot_compare_auqc(dict_all_models, y_true, t_true, bins=100)
